# %%
from waitress import serve
from dash_trial4 import app

if __name__ == '__main__':
    serve(app.server, host='0.0.0.0', port=8050)
# Out:
# ERROR:dash_trial4:Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\dash\dash.py", line 1283, in dispatch
#     ctx.run(
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\dash\_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\HuangRunchen\Documents\dash-app\trial\dash_trial4.py", line 96, in parse_excel
#     content_type, content_string = contents.split(',')
# AttributeError: 'NoneType' object has no attribute 'split'
# C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning:
#
# Conditional Formatting extension is not supported and will be removed
#
# ERROR:dash_trial4:Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\dash\dash.py", line 1283, in dispatch
#     ctx.run(
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\dash\_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\HuangRunchen\Documents\dash-app\trial\dash_trial4.py", line 96, in parse_excel
#     content_type, content_string = contents.split(',')
# AttributeError: 'NoneType' object has no attribute 'split'
# C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning:
#
# Conditional Formatting extension is not supported and will be removed
#
# WARNING:waitress.queue:Task queue depth is 1
# WARNING:waitress.queue:Task queue depth is 2
# WARNING:waitress.queue:Task queue depth is 2
# WARNING:waitress.queue:Task queue depth is 2
# WARNING:waitress.queue:Task queue depth is 3
# WARNING:waitress.queue:Task queue depth is 1
# ERROR:dash_trial4:Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\dash\dash.py", line 1283, in dispatch
#     ctx.run(
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\dash\_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\HuangRunchen\Documents\dash-app\trial\dash_trial4.py", line 96, in parse_excel
#     content_type, content_string = contents.split(',')
# AttributeError: 'NoneType' object has no attribute 'split'
# C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning:
#
# Conditional Formatting extension is not supported and will be removed
#
# C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning:
#
# Conditional Formatting extension is not supported and will be removed
#
# ERROR:dash_trial4:Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\dash\dash.py", line 1283, in dispatch
#     ctx.run(
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\dash\_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\HuangRunchen\Documents\dash-app\trial\dash_trial4.py", line 96, in parse_excel
#     content_type, content_string = contents.split(',')
# AttributeError: 'NoneType' object has no attribute 'split'
# C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning:
#
# Conditional Formatting extension is not supported and will be removed
#
# ERROR:dash_trial4:Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\dash\dash.py", line 1283, in dispatch
#     ctx.run(
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\dash\_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\HuangRunchen\Documents\dash-app\trial\dash_trial4.py", line 96, in parse_excel
#     content_type, content_string = contents.split(',')
# AttributeError: 'NoneType' object has no attribute 'split'
# C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning:
#
# Conditional Formatting extension is not supported and will be removed
# ERROR:dash_trial4:Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\dash\dash.py", line 1283, in dispatch
#     ctx.run(
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\dash\_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\HuangRunchen\Documents\dash-app\trial\dash_trial4.py", line 96, in parse_excel
#     content_type, content_string = contents.split(',')
# AttributeError: 'NoneType' object has no attribute 'split'
# C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning:
#
# Conditional Formatting extension is not supported and will be removed
#
# ERROR:dash_trial4:Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\dash\dash.py", line 1283, in dispatch
#     ctx.run(
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\dash\_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\HuangRunchen\Documents\dash-app\trial\dash_trial4.py", line 96, in parse_excel
#     content_type, content_string = contents.split(',')
# AttributeError: 'NoneType' object has no attribute 'split'
# ERROR:dash_trial4:Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\dash\dash.py", line 1283, in dispatch
#     ctx.run(
#   File "C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\dash\_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\HuangRunchen\Documents\dash-app\trial\dash_trial4.py", line 96, in parse_excel
#     content_type, content_string = contents.split(',')
# AttributeError: 'NoneType' object has no attribute 'split'
# C:\Users\HuangRunchen\AppData\Local\anaconda3\envs\dashapp\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning:
#
# Conditional Formatting extension is not supported and will be removed
